# %% [markdown]
# # Extract MMU Program (By Faculty)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

base_url = "https://www.mmu.edu.my/programmes/"
headers = {'User-Agent': 'Mozilla/5.0'}

# Step 1: Get all faculty links
response = requests.get(base_url, headers=headers)
soup = BeautifulSoup(response.content, "html.parser")

faculty_links = []

# Select only the first div.col-md-4 inside div.row
first_col = soup.select("div.row div.col-md-4:first-of-type")

# Loop through the first div.col-md-4 only
for col in first_col:
    dropdown = col.select_one("ul.programme-dropdown")
    if dropdown:
        for tag in dropdown.select("li a"):
            name = tag.text.strip()
            href = tag.get("href")
            if href:
                faculty_links.append((name, href))

# Step 2-4: Loop through each faculty and extract programmes + entry requirements
programmes_data = []

for faculty_name, faculty_url in faculty_links:
    print(f"Processing faculty: {faculty_name}")
    try:
        faculty_res = requests.get(faculty_url, headers=headers)
        faculty_soup = BeautifulSoup(faculty_res.content, "html.parser")

        # Find programme links in this faculty page
        programme_tags = faculty_soup.select("div.faculty-programmes ul li a")

        for prog_tag in programme_tags:
            prog_name = prog_tag.text.strip()
            prog_url = prog_tag["href"]
            print(f"  -> Programme: {prog_name}")

            # Step 4: Visit programme page and get entry requirements
            prog_res = requests.get(prog_url, headers=headers)
            prog_soup = BeautifulSoup(prog_res.content, "html.parser")

            # Get the <ul class="course-dropdown"> content
            entry_ul = prog_soup.select_one("ul.course-dropdown")
            entry_req = entry_ul.get_text(separator=" ", strip=True) if entry_ul else "Not Found"

            programmes_data.append({
                "faculty": faculty_name,
                "programme": prog_name,
                "entry_requirement": entry_req
            })

            time.sleep(0.5)  # Be gentle with the server

    except Exception as e:
        print(f"Error processing {faculty_name}: {e}")

# Step 5: Save to DataFrame and CSV
df = pd.DataFrame(programmes_data)
df.to_csv("mmu_faculty_programmes.csv", index=False)
print("\n✅ Data saved to 'mmu_faculty_programmes.csv'")
# Out:
# Processing faculty: Faculty of Cinematic Arts (FCA)
#   -> Programme: Diploma in Cinematography
#   -> Programme: Bachelor of Cinematic Arts (Hons.)
# Processing faculty: Faculty of Law (FOL)
#   -> Programme: Master of Laws (By Research)
#   -> Programme: Doctor of Philosophy (Ph.D.) Laws (By Research)
#   -> Programme: Foundation in Law
#   -> Programme: Bachelor of Law (Hons.)
# Processing faculty: Faculty of Engineering & Technology (FET)
#   -> Programme: Master of Engineering Science (By Research)
#   -> Programme: Doctor of Philosophy (Ph.D.) Engineering (By Research)
#   -> Programme: Foundation in Engineering
#   -> Programme: Diploma in Electronic Engineering
#   -> Programme: Diploma in Mechanical Engineering
#   -> Programme: Bachelor of Engineering (Hons.) Electronics majoring in Telecommunications
#   -> Programme: Bachelor of Electronics Engineering (Robotics & Automation) with Honours
#   -> Programme: Bachelor of Mechanical Engineering with Honours
# Processing faculty: Faculty of Artificial Intelligence & Engineering (FAIE)
#   -> Programme: Master of Engineering Science (By Research)
#   -> Programme: Doctor of Philosophy (Ph.D.) Engineering (By Research)
#   -> Programme: Master of Science in Engineering Business Management
#   -> Programme: Master of Engineering in Telecommunications
#   -> Programme: Foundation in Engineering
#   -> Programme: Bachelor of Science (Hons.) Intelligent Robotics
#   -> Programme: Bachelor of Engineering (Hons.) Electrical
#   -> Programme: Bachelor of Engineering (Hons.) Electronics
#   -> Programme: Bachelor of Engineering (Hons.) Electronics and Telecommunications
#   -> Programme: Bachelor of Engineering (Hons.) Electronics majoring in Computer
# Processing faculty: Faculty of Computing & Informatics (FCI)
#   -> Programme: Master of Computing (By Research)
#   -> Programme: Master of Computer Science via ODL (By Coursework)
#   -> Programme: Doctor of Philosophy (Ph.D.) in Computing (By Research)
#   -> Programme: Bachelor of Digital Enterprise Management (Hons.)
#   -> Programme: Bachelor of Science (Hons.) Intelligent Robotics
#   -> Programme: Foundation in Computing
#   -> Programme: Diploma in Information Technology
#   -> Programme: Bachelor of Computer Science (Hons.)
#   -> Programme: Bachelor of Information Technology (Hons.) Information Systems
# Processing faculty: Open and Distance Learning (ODL)
#   -> Programme: Executive Master of Business Administration (E.M.B.A) via ODL (By Coursework)
#   -> Programme: Bachelor of Management (Hons.)
#   -> Programme: Master of Computer Science via ODL (By Coursework)
#   -> Programme: Master of Information Technology via ODL (By Coursework)
# Processing faculty: Faculty of Information Science & Technology (FIST)
#   -> Programme: Diploma in Information Technology
#   -> Programme: Master of Computing (By Research)
#   -> Programme: Master of Information Technology via ODL (By Coursework)
#   -> Programme: Doctor of Philosophy (Ph.D.) in Computing (By Research)
#   -> Programme: Foundation in Science & Technology
#   -> Programme: Bachelor of Information Technology (Hons.) Data Communications and Networking
#   -> Programme: Bachelor of Information Technology (Hons.) Business Intelligence and Analytics
#   -> Programme: Bachelor of Computer Science (Hons.) Artificial Intelligence
#   -> Programme: Bachelor of Information Technology (Hons.) Security Technology
#   -> Programme: Bachelor of Science (Hons.) Bioinformatics
# Processing faculty: Faculty of Management (FOM)
#   -> Programme: Executive Master of Business Administration (E.M.B.A) via ODL (By Coursework)
#   -> Programme: Diploma in Management
#   -> Programme: Diploma in Finance
#   -> Programme: Bachelor of Management (Hons.)
#   -> Programme: Master of Philosophy (Management) (By Research)
#   -> Programme: Doctor of Philosophy (Ph.D.) Management (By Research)
#   -> Programme: Master of Business Administration (M.B.A) (By Coursework)
#   -> Programme: Doctor of Business Administration (By Coursework and Dissertation)
#   -> Programme: Foundation in Management
#   -> Programme: Bachelor in Accounting (Hons.)
#   -> Programme: Bachelor of Analytical Economics (Hons.)
#   -> Programme: Bachelor of Finance (Hons.)
#   -> Programme: Bachelor of Business Management (Hons.)
#   -> Programme: Bachelor of Marketing (Hons.)
#   -> Programme: Bachelor of Digital Enterprise Management (Hons.)
# Processing faculty: Faculty of Creative Multimedia (FCM)
#   -> Programme: Master of Creative Multimedia (By Coursework)
#   -> Programme: Foundation in Creative Multimedia
#   -> Programme: Diploma in 3D Modelling and Animation
#   -> Programme: Diploma in Creative Audio
#   -> Programme: Diploma in Creative Multimedia
#   -> Programme: Master of Science (Creative Multimedia) (By Research)
#   -> Programme: Doctor of Philosophy (Ph.D.) Creative Multimedia (By Research)
#   -> Programme: Bachelor of Multimedia (Hons.) Advertising Design
#   -> Programme: Bachelor of Multimedia (Hons) Animation
#   -> Programme: Bachelor of Immersive Media Design (Hons)
#   -> Programme: Bachelor of Multimedia (Hons) Visual Effects
# Processing faculty: Faculty of Applied Communication (FAC)
#   -> Programme: Master of Philosophy in Communication (By Research)
#   -> Programme: Doctor of Philosophy (Ph.D.) – Communication (By Research)
#   -> Programme: Foundation in Communication Program
#   -> Programme: Diploma in Applied Communication
#   -> Programme: Bachelor of Communication (Strategic Communication) (Hons)
# Processing faculty: Faculty of Business (FOB)
#   -> Programme: Diploma in Digital Business
#   -> Programme: Master of Philosophy (Management) (By Research)
#   -> Programme: Doctor of Philosophy (Ph.D.) Management (By Research)
#   -> Programme: Master of Business Administration (M.B.A) (By Coursework)
#   -> Programme: Foundation in Business
#   -> Programme: Diploma in Business Administration
#   -> Programme: Diploma in Accounting
#   -> Programme: Bachelor in Accounting (Hons.)
#   -> Programme: Bachelor of Business Administration (Hons.) Banking and Finance
#   -> Programme: Bachelor of Business Administration (Hons.) Human Resource Management
#   -> Programme: Bachelor of Business Administration (Hons.) International Business
#   -> Programme: Bachelor of Business Administration (Hons.) Marketing Management
#   -> Programme: Bachelor of Business Administration (Hons.) Digital Business Management
#
# ✅ Data saved to 'mmu_faculty_programmes.csv'

# %% [markdown]
# # EDA
# - **Findings:** same programme offered by different faculty

# %%
import pandas as pd
df = pd.read_csv("mmu_faculty_programmes.csv")

print(df['faculty'].nunique())
print(df['programme'].nunique())

filtered_df = df[df.duplicated(subset='programme', keep=False)]
filtered_df
# Out:
# 11
# 75
#                                               faculty  \
# 6           Faculty of Engineering & Technology (FET)
# 7           Faculty of Engineering & Technology (FET)
# 8           Faculty of Engineering & Technology (FET)
# 14  Faculty of Artificial Intelligence & Engineeri...
# 15  Faculty of Artificial Intelligence & Engineeri...
# 18  Faculty of Artificial Intelligence & Engineeri...
# 19  Faculty of Artificial Intelligence & Engineeri...
# 24           Faculty of Computing & Informatics (FCI)
# 25           Faculty of Computing & Informatics (FCI)
# 26           Faculty of Computing & Informatics (FCI)
# 27           Faculty of Computing & Informatics (FCI)
# 28           Faculty of Computing & Informatics (FCI)
# 30           Faculty of Computing & Informatics (FCI)
# 33                   Open and Distance Learning (ODL)
# 34                   Open and Distance Learning (ODL)
# 35                   Open and Distance Learning (ODL)
# 36                   Open and Distance Learning (ODL)
# 37  Faculty of Information Science & Technology (F...
# 38  Faculty of Information Science & Technology (F...
# 39  Faculty of Information Science & Technology (F...
# 40  Faculty of Information Science & Technology (F...
# 47                        Faculty of Management (FOM)
# 50                        Faculty of Management (FOM)
# 51                        Faculty of Management (FOM)
# 52                        Faculty of Management (FOM)
# 53                        Faculty of Management (FOM)
# 56                        Faculty of Management (FOM)
# 61                        Faculty of Management (FOM)
# 79                          Faculty of Business (FOB)
# 80                          Faculty of Business (FOB)
# 81                          Faculty of Business (FOB)
# 85                          Faculty of Business (FOB)
#
#                                             programme  \
# 6         Master of Engineering Science (By Research)
# 7   Doctor of Philosophy (Ph.D.) Engineering (By R...
# 8                           Foundation in Engineering
# 14        Master of Engineering Science (By Research)
# 15  Doctor of Philosophy (Ph.D.) Engineering (By R...
# 18                          Foundation in Engineering
# 19   Bachelor of Science (Hons.) Intelligent Robotics
# 24                  Master of Computing (By Research)
# 25  Master of Computer Science via ODL (By Coursew...
# 26  Doctor of Philosophy (Ph.D.) in Computing (By ...
# 27  Bachelor of Digital Enterprise Management (Hons.)
# 28   Bachelor of Science (Hons.) Intelligent Robotics
# 30                  Diploma in Information Technology
# 33  Executive Master of Business Administration (E...
# 34                     Bachelor of Management (Hons.)
# 35  Master of Computer Science via ODL (By Coursew...
# 36  Master of Information Technology via ODL (By C...
# 37                  Diploma in Information Technology
# 38                  Master of Computing (By Research)
# 39  Master of Information Technology via ODL (By C...
# 40  Doctor of Philosophy (Ph.D.) in Computing (By ...
# 47  Executive Master of Business Administration (E...
# 50                     Bachelor of Management (Hons.)
# 51    Master of Philosophy (Management) (By Research)
# 52  Doctor of Philosophy (Ph.D.) Management (By Re...
# 53  Master of Business Administration (M.B.A) (By ...
# 56                     Bachelor in Accounting (Hons.)
# 61  Bachelor of Digital Enterprise Management (Hons.)
# 79    Master of Philosophy (Management) (By Research)
# 80  Doctor of Philosophy (Ph.D.) Management (By Re...
# 81  Master of Business Administration (M.B.A) (By ...
# 85                     Bachelor in Accounting (Hons.)
#
#                                     entry_requirement
# 6   Fields of Research 2-D/3-D Modelling and Recon...
# 7   Fields of Research 2-D/3-D Modelling and Recon...
# 8   Entry Requirements Pass SPM/O-Level or its equ...
# 14  Fields of Research (but not limited to) 5G Mob...
# 15  Fields of Research (but not limited to) 5G Mob...
# 18  Entry Requirements Pass SPM/O-Level or its equ...
# 19  Entry Requirements Pass Foundation / Matricula...
# 24  Fields of Research Artificial Intelligence Bio...
# 25  Entry Requirements A Bachelor’s degree (Level ...
# 26  Fields of Research Artificial Intelligence Bio...
# 27  Entry Requirements Pass Foundation/ Matriculat...
# 28  Entry Requirements Pass Foundation / Matricula...
# 30  Programme Structure Core Trimester 1 Computer ...
# 33  Entry Requirements A Bachelor’s degree (Level ...
# 34  Entry Requirements Pass Foundation/ Matriculat...
# 35  Entry Requirements A Bachelor’s degree (Level ...
# 36  Entry Requirements A Bachelor’s degree (Level ...
# 37                                          Not Found
# 38  Fields of Research Security Technology Cryptog...
# 39  Entry Requirements A Bachelor’s degree (Level ...
# 40  Fields of Research Security Technology Cryptog...
# 47  Entry Requirements A Bachelor’s degree (Level ...
# 50  Entry Requirements Pass Foundation/ Matriculat...
# 51  Fields of Research Human resource management I...
# 52  Fields of Research Human resource management I...
# 53  Entry Requirements A Bachelor’s degree (Level ...
# 56  Entry Requirements A pass in Matriculation/Fou...
# 61  Entry Requirements Pass Foundation/ Matriculat...
# 79  Fields of Research Accounting & Governance Mar...
# 80  Fields of Research Human resource management I...
# 81  Entry Requirements A Bachelor’s degree (Level ...
# 85  Entry Requirements A pass in Matriculation/Fou...

# %% [markdown]
# # Data Preprocessing
# - Remove foundation, master, and doctor
# - Keep programme for diploma and bachelor degree only

# %%
import pandas as pd

df = pd.read_csv("mmu_faculty_programmes.csv")
# Keywords to check for
keywords = ['foundation', 'master', 'doctor']

# Filter rows where Column C contains any of the specified keywords
df_filtered = df[~df['programme'].str.contains('|'.join(keywords), case=False, na=False)]

display(df_filtered)
df_filtered.to_csv("preprocessed_programme.csv",index=False)
# Out:
#                                               faculty  \
# 0                     Faculty of Cinematic Arts (FCA)
# 1                     Faculty of Cinematic Arts (FCA)
# 5                                Faculty of Law (FOL)
# 9           Faculty of Engineering & Technology (FET)
# 10          Faculty of Engineering & Technology (FET)
# 11          Faculty of Engineering & Technology (FET)
# 12          Faculty of Engineering & Technology (FET)
# 13          Faculty of Engineering & Technology (FET)
# 19  Faculty of Artificial Intelligence & Engineeri...
# 20  Faculty of Artificial Intelligence & Engineeri...
# 21  Faculty of Artificial Intelligence & Engineeri...
# 22  Faculty of Artificial Intelligence & Engineeri...
# 23  Faculty of Artificial Intelligence & Engineeri...
# 27           Faculty of Computing & Informatics (FCI)
# 28           Faculty of Computing & Informatics (FCI)
# 30           Faculty of Computing & Informatics (FCI)
# 31           Faculty of Computing & Informatics (FCI)
# 32           Faculty of Computing & Informatics (FCI)
# 34                   Open and Distance Learning (ODL)
# 37  Faculty of Information Science & Technology (F...
# 42  Faculty of Information Science & Technology (F...
# 43  Faculty of Information Science & Technology (F...
# 44  Faculty of Information Science & Technology (F...
# 45  Faculty of Information Science & Technology (F...
# 46  Faculty of Information Science & Technology (F...
# 48                        Faculty of Management (FOM)
# 49                        Faculty of Management (FOM)
# 50                        Faculty of Management (FOM)
# 56                        Faculty of Management (FOM)
# 57                        Faculty of Management (FOM)
# 58                        Faculty of Management (FOM)
# 59                        Faculty of Management (FOM)
# 60                        Faculty of Management (FOM)
# 61                        Faculty of Management (FOM)
# 64               Faculty of Creative Multimedia (FCM)
# 65               Faculty of Creative Multimedia (FCM)
# 66               Faculty of Creative Multimedia (FCM)
# 69               Faculty of Creative Multimedia (FCM)
# 70               Faculty of Creative Multimedia (FCM)
# 71               Faculty of Creative Multimedia (FCM)
# 72               Faculty of Creative Multimedia (FCM)
# 76             Faculty of Applied Communication (FAC)
# 77             Faculty of Applied Communication (FAC)
# 78                          Faculty of Business (FOB)
# 83                          Faculty of Business (FOB)
# 84                          Faculty of Business (FOB)
# 85                          Faculty of Business (FOB)
# 86                          Faculty of Business (FOB)
# 87                          Faculty of Business (FOB)
# 88                          Faculty of Business (FOB)
# 89                          Faculty of Business (FOB)
# 90                          Faculty of Business (FOB)
#
#                                             programme  \
# 0                           Diploma in Cinematography
# 1                  Bachelor of Cinematic Arts (Hons.)
# 5                             Bachelor of Law (Hons.)
# 9                   Diploma in Electronic Engineering
# 10                  Diploma in Mechanical Engineering
# 11  Bachelor of Engineering (Hons.) Electronics ma...
# 12  Bachelor of Electronics Engineering (Robotics ...
# 13    Bachelor of Mechanical Engineering with Honours
# 19   Bachelor of Science (Hons.) Intelligent Robotics
# 20         Bachelor of Engineering (Hons.) Electrical
# 21        Bachelor of Engineering (Hons.) Electronics
# 22  Bachelor of Engineering (Hons.) Electronics an...
# 23  Bachelor of Engineering (Hons.) Electronics ma...
# 27  Bachelor of Digital Enterprise Management (Hons.)
# 28   Bachelor of Science (Hons.) Intelligent Robotics
# 30                  Diploma in Information Technology
# 31               Bachelor of Computer Science (Hons.)
# 32  Bachelor of Information Technology (Hons.) Inf...
# 34                     Bachelor of Management (Hons.)
# 37                  Diploma in Information Technology
# 42  Bachelor of Information Technology (Hons.) Dat...
# 43  Bachelor of Information Technology (Hons.) Bus...
# 44  Bachelor of Computer Science (Hons.) Artificia...
# 45  Bachelor of Information Technology (Hons.) Sec...
# 46         Bachelor of Science (Hons.) Bioinformatics
# 48                              Diploma in Management
# 49                                 Diploma in Finance
# 50                     Bachelor of Management (Hons.)
# 56                     Bachelor in Accounting (Hons.)
# 57           Bachelor of Analytical Economics (Hons.)
# 58                        Bachelor of Finance (Hons.)
# 59            Bachelor of Business Management (Hons.)
# 60                      Bachelor of Marketing (Hons.)
# 61  Bachelor of Digital Enterprise Management (Hons.)
# 64              Diploma in 3D Modelling and Animation
# 65                          Diploma in Creative Audio
# 66                     Diploma in Creative Multimedia
# 69  Bachelor of Multimedia (Hons.) Advertising Design
# 70            Bachelor of Multimedia (Hons) Animation
# 71          Bachelor of Immersive Media Design (Hons)
# 72       Bachelor of Multimedia (Hons) Visual Effects
# 76                   Diploma in Applied Communication
# 77  Bachelor of Communication (Strategic Communica...
# 78                        Diploma in Digital Business
# 83                 Diploma in Business Administration
# 84                              Diploma in Accounting
# 85                     Bachelor in Accounting (Hons.)
# 86  Bachelor of Business Administration (Hons.) Ba...
# 87  Bachelor of Business Administration (Hons.) Hu...
# 88  Bachelor of Business Administration (Hons.) In...
# 89  Bachelor of Business Administration (Hons.) Ma...
# 90  Bachelor of Business Administration (Hons.) Di...
#
#                                     entry_requirement
# 0   Entry Requirements Pass SPM/O-Level or its equ...
# 1   Entry Requirements Pass Foundation/Matriculati...
# 5   Entry Requirements Pass Foundation/Matriculati...
# 9   Entry Requirements Pass SPM/O-Level or its equ...
# 10  Entry Requirements Pass SPM/O-Level or its equ...
# 11  Entry Requirements Pass Foundation/Matriculati...
# 12  Entry Requirements Pass Foundation/Matriculati...
# 13  Entry Requirements Pass Foundation/Matriculati...
# 19  Entry Requirements Pass Foundation / Matricula...
# 20  Entry Requirements Pass Foundation/Matriculati...
# 21  Entry Requirements Pass Foundation/Matriculati...
# 22  Entry Requirements Pass Foundation/Matriculati...
# 23  Entry Requirements Pass Foundation/Matriculati...
# 27  Entry Requirements Pass Foundation/ Matriculat...
# 28  Entry Requirements Pass Foundation / Matricula...
# 30  Programme Structure Core Trimester 1 Computer ...
# 31  Programme Structure Core Year 1 Calculus Progr...
# 32  Programme Structure Core Year 1 Introduction t...
# 34  Entry Requirements Pass Foundation/ Matriculat...
# 37                                          Not Found
# 42                                 Entry Requirements
# 43                                 Entry Requirements
# 44  Programme Structure Core Year 1 Computer Archi...
# 45                                 Entry Requirements
# 46  Entry Requirements Pass Foundation / Matricula...
# 48  Entry Requirements Pass SPM/O-Level or its equ...
# 49  Entry Requirements Pass SPM / O-Level or its e...
# 50  Entry Requirements Pass Foundation/ Matriculat...
# 56  Entry Requirements A pass in Matriculation/Fou...
# 57  Entry Requirements Pass Foundation/ Matriculat...
# 58  Entry Requirements Pass Foundation/Matriculati...
# 59  Entry Requirements Pass Foundation/ Matriculat...
# 60  Entry Requirements Pass Foundation/ Matriculat...
# 61  Entry Requirements Pass Foundation/ Matriculat...
# 64  Entry Requirements Pass SPM/O-Level or its equ...
# 65  Entry Requirements Pass SPM/O-Level or its equ...
# 66  Entry Requirements Pass SPM/O-Level or its equ...
# 69  Entry Requirements Pass Foundation/Matriculati...
# 70  Entry Requirements Pass Foundation/Matriculati...
# 71  Entry Requirements Pass Foundation/Matriculati...
# 72  Entry Requirements Pass Foundation/Matriculati...
# 76  Entry Requirements Pass in SPM /O-Level or its...
# 77  Entry Requirements Pass Matriculation / Founda...
# 78  Entry Requirements Pass SPM/O-Level or its equ...
# 83  Entry Requirements Pass SPM/O-Level or its equ...
# 84  Entry Requirements Pass SPM/O-Level or its equ...
# 85  Entry Requirements A pass in Matriculation/Fou...
# 86  Entry Requirements Pass Foundation/ Matriculat...
# 87  Entry Requirements Pass Foundation/ Matriculat...
# 88  Entry Requirements Pass Foundation/ Matriculat...
# 89  Entry Requirements Pass Foundation/ Matriculat...
# 90  Entry Requirements Pass Foundation/ Matriculat...
